# %%
print("HEllo World")
# Out:
# HEllo World

# %%
## List comprehension
list = []
for a in range(11):
    list.append(a**2)
print(list)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
## Wap to find the leap year
year = int(input("Enter the year: "))
if year % 4 == 0 and year % 100 != 0 or (year % 400 == 0):
    print(f"{year} is a leap year.")
# Out:
# 2024 is a leap year.

# %%
tur = tuple()
print(type(tur))
# Out:
# <class 'tuple'>

# %%
## wap to make a simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")
if operation == '+':
    print(f"{num1} + {num2} = {num1 + num2}")
elif operation == '-':
    print(f"{num1} - {num2} = {num1 - num2}")
elif operation == '*':
    print(f"{num1} * {num2} = {num1 * num2}")
elif operation == '/':
    if num2 != 0:
        print(f"{num1} / {num2} = {num1 / num2}")
    else:
        print("Error: Division by zero is not allowed.")
else:
    print("Invalid operation.")
# Out:
# 2024.0 + 2.0 = 2026.0

# %%
tup = (1, 2, 3, 4, 5)
first, *middle, last = tup
print("First:", first)
print("Middle:", middle)
print("Last:", last)
# Out:
# First: 1
# Middle: [2, 3, 4]
# Last: 5

# %%
## wap to creste a example of nested tuple
nested_tup = (1, 2, (3, 4), (5, 6, 7))
print(nested_tup)
print(nested_tup[2])  # Output: (3, 4)
print(nested_tup[2][0])  # Output: 3    
print(nested_tup[3][1])  # Output: 6
# Out:
# (1, 2, (3, 4), (5, 6, 7))
# (3, 4)
# 3
# 6
