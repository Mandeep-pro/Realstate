# %%
import logging

## create a logger for mudule
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

## create a logger for module 2

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.ERROR)


## configure logging settings
logging.basicConfig(
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    level=logging.DEBUG,
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
## log message with different loggers
logger1.debug("This is a debug message from module 1")
logger1.warning("This is an warning message from module 1")
logger2.error("This is an error message from module 2")
# Out:
# 2026-01-24 22:22:18 - module1 - DEBUG - This is a debug message from module 1
# 2026-01-24 22:22:18 - module1 - WARNING - This is an warning message from module 1
# 2026-01-24 22:22:18 - module2 - ERROR - This is an error message from module 2
